# %%
# !pip install torch ultralytics torch torchvision torchaudio opencv-python-headless
# Out:
# ...
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.8 MB 330.3 kB/s eta 0:01:58
#    ---------------------------------------- 0.1/38.8 MB 655.4 kB/s eta 0:00:59
#    ---------------------------------------- 0.1/38.8 MB 711.9 kB/s eta 0:00:55
#    ---------------------------------------- 0.3/38.8 MB 1.2 MB/s eta 0:00:32
#     --------------------------------------- 0.5/38.8 MB 1.7 MB/s eta 0:00:23
#     --------------------------------------- 0.8/38.8 MB 2.2 MB/s eta 0:00:18
#    - -------------------------------------- 1.0/38.8 MB 2.3 MB/s eta 0:00:17
#    - -------------------------------------- 1.0/38.8 MB 2.3 MB/s eta 0:00:17
#    - -------------------------------------- 1.1/38.8 MB 2.2 MB/s eta 0:00:18
#    - -------------------------------------- 1.3/38.8 MB 2.2 MB/s eta 0:00:18
#    - -------------------------------------- 1.5/38.8 MB 2.4 MB/s eta 0:00:16
# ...

# %%
import torch

# Model
model = torch.hub.load("ultralytics/yolov5", "yolov5s")
# Out:
# Using cache found in C:\Users\haric/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2024-8-29 Python-3.12.4 torch-2.4.0+cpu CPU
#
# ...
# 100%|██████████| 14.1M/14.1M [00:05<00:00, 2.51MB/s]
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...
